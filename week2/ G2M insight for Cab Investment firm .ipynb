# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import datetime
import warnings 
warnings.filterwarnings('ignore')

# %%
Cab_Data= pd.read_csv("DataSets/Cab_Data.csv")
city = pd.read_csv("DataSets/City.csv")
customer_id = pd.read_csv("DataSets/Customer_ID.csv")
transaction_id = pd.read_csv("DataSets/Transaction_ID.csv")

# %%
Cab_Data.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
Cab_Data.tail()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192

# %%
Cab_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
Cab_Data.shape
# Out:
# (359392, 7)

# %%
Cab_Data.dtypes
# Out:
# Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
Cab_Data.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city.tail()
# Out:
#              City Population      Users
# 15  SACRAMENTO CA   545,776      7,044
# 16  PITTSBURGH PA   542,085      3,643
# 17  WASHINGTON DC   418,859    127,001
# 18   NASHVILLE TN   327,225      9,270
# 19      BOSTON MA   248,968     80,021

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes

# %%
city.shape
# Out:
# (20, 3)

# %%
city.dtypes
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
city.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
customer_id.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
customer_id.tail()
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128

# %%
customer_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_id.shape
# Out:
# (49171, 4)

# %%
customer_id.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
customer_id.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
transaction_id.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
transaction_id.tail()
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card

# %%
transaction_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
transaction_id.shape
# Out:
# (440098, 3)

# %%
transaction_id.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
transaction_id.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
Cab_Data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
city.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
customer_id.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
transaction_id.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
for col in Cab_Data.columns:
    if ' ' in col:
        Cab_Data = Cab_Data.rename(columns={col:col.replace(' ','_')})

# %%
Cab_Data.columns
# Out:
# Index(['Transaction_ID', 'Date_of_Travel', 'Company', 'City', 'KM_Travelled',
#        'Price_Charged', 'Cost_of_Trip'],
#       dtype='object')

# %%
for col in customer_id.columns:
    if ' ' in col:
        customer_id = customer_id.rename(columns={col:col.replace(' ','_')})

# %%
customer_id.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Income_(USD/Month)'], dtype='object')

# %%
for col in transaction_id.columns:
    if ' ' in col:
        transaction_id = transaction_id.rename(columns={col:col.replace(' ','_')})

# %%
transaction_id.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Payment_Mode'], dtype='object')

# %%
from datetime import datetime, timedelta
def to_date_format(n):
    date_str = (datetime(1899,12,30)+ timedelta(n-1)).strftime("%d/%m/%Y")
    date_date = datetime.strptime(date_str, "%d/%m/%Y")
    return date_date

# %%
Cab_Data['Date_of_Travel'] = Cab_Data['Date_of_Travel'].apply(lambda x:to_date_format(x))

# %%
Cab_Data.head()
# Out:
#    Transaction_ID Date_of_Travel   Company        City  KM_Travelled  \
# 0        10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-05  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-06  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-02  Pink Cab  ATLANTA GA          8.73
#
#    Price_Charged  Cost_of_Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
months=[]
years=[]
for i in range(len(Cab_Data['Date_of_Travel'])):
    months.append(Cab_Data['Date_of_Travel'][i].month)
    years.append(Cab_Data['Date_of_Travel'][i].year)

Cab_Data['Month']=months
Cab_Data['Year']=years

Cab_Data.drop('Date_of_Travel', axis=1, inplace= True)

# %%
pinkcab = Cab_Data[Cab_Data['Company']=='Pink Cab']
yellowcab = Cab_Data[Cab_Data['Company']=='Yellow Cab']

# %%
Cab_Data.head()
# Out:
#    Transaction_ID   Company        City  KM_Travelled  Price_Charged  \
# 0        10000011  Pink Cab  ATLANTA GA         30.45         370.95
# 1        10000012  Pink Cab  ATLANTA GA         28.62         358.52
# 2        10000013  Pink Cab  ATLANTA GA          9.04         125.20
# 3        10000014  Pink Cab  ATLANTA GA         33.17         377.40
# 4        10000015  Pink Cab  ATLANTA GA          8.73         114.62
#
#    Cost_of_Trip  Month  Year
# 0       313.635      1  2016
# 1       334.854      1  2016
# 2        97.632      1  2016
# 3       351.602      1  2016
# 4        97.776      1  2016

# %%
plot1 = Cab_Data[Cab_Data.Company=='Pink Cab'].groupby(['Month']).Transaction_ID.count()
plot1
# Out:
# Month
# 1      4825
# 2      3392
# 3      4228
# 4      4140
# 5      5023
# 6      5820
# 7      6585
# 8      8061
# 9      9647
# 10    10366
# 11    11324
# 12    11300
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=plot1.index, y=plot1.values)
plt.title('travel frequency by months (pink cab)',fontsize=13)
plt.xlabel('month', fontsize=13)
plt.ylabel('value',fontsize=13)
plt.show()

# %%
plot2 = Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby(['Month']).Transaction_ID.count()
plot2
# Out:
# Month
# 1     17468
# 2     14928
# 3     17516
# 4     17535
# 5     18809
# 6     18656
# 7     21074
# 8     24328
# 9     27356
# 10    29609
# 11    32609
# 12    34793
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=plot2.index, y=plot2.values)
plt.title('travel frequency by months (yellow cab)',fontsize=13)
plt.xlabel('month', fontsize=13)
plt.ylabel('value',fontsize=13)
plt.show()

# %%
overall_distance = Cab_Data['KM_Travelled'].describe()
pinkcab_distance = pinkcab['KM_Travelled'].describe()
yellowcab_distance = yellowcab['KM_Travelled'].describe()

# %%
df = pd.DataFrame({'overall': overall_distance.values, 'pinkcab':pinkcab_distance.values,'yellowcab': yellowcab_distance.values }, index=['count','mean','std.dev','min','25%','50%','75%','max'])
df
# Out:
#                overall       pinkcab      yellowcab
# count    359392.000000  84711.000000  274681.000000
# mean         22.567254     22.559917      22.569517
# std.dev      12.233526     12.231092      12.234298
# min           1.900000      1.900000       1.900000
# 25%          12.000000     12.000000      11.990000
# 50%          22.440000     22.440000      22.440000
# 75%          32.960000     32.960000      32.960000
# max          48.000000     48.000000      48.000000

# %%
ax = sns.distplot(pinkcab['KM_Travelled'],kde=False, color='pink', bins= 80)
plt.title("Analyze kilometers traveled distribution (pinkcab)", fontsize=14, y=1)
plt.xlabel("KM Travelled", labelpad=12)
plt.ylabel("frequency", labelpad=12)
# Out:
# Text(0, 0.5, 'frequency')

# %%
ax = sns.distplot(yellowcab['KM_Travelled'],kde=False, color='pink', bins= 80)
plt.title("Analyze kilometers traveled distribution (yellowcab)", fontsize=14, y=1)
plt.xlabel("KM Travelled", labelpad=12)
plt.ylabel("frequency", labelpad=12)
# Out:
# Text(0, 0.5, 'frequency')

# %%
overall_price =Cab_Data['Price_Charged'].describe()
pinkcab_price = pinkcab['Price_Charged'].describe()
yellowcab_price = yellowcab['Price_Charged'].describe()

# %%
df = pd.DataFrame({'overall': overall_price.values, 'pinkcab':pinkcab_price.values,'yellowcab': yellowcab_price.values }, index=['count','mean','std.dev','min','25%','50%','75%','max'])
df
# Out:
#                overall       pinkcab      yellowcab
# count    359392.000000  84711.000000  274681.000000
# mean        423.443311    310.800856     458.181990
# std.dev     274.378911    181.995661     288.386166
# min          15.600000     15.600000      20.730000
# 25%         206.437500    159.970000     226.680000
# 50%         386.360000    298.060000     425.060000
# 75%         583.660000    441.505000     633.880000
# max        2048.030000   1623.480000    2048.030000

# %%
fig, (axp, axy)= plt.subplots(ncols=2, figsize=(15,7))
sns.boxplot(pinkcab['Price_Charged'], ax=axp)
axp.set_title('pink cab',fontsize=14)
sns.boxplot(yellowcab['Price_Charged'], ax=axy)
axy.set_title('yellow cab',fontsize=14)
plt.show()

# %%
fig, (axp, axy) = plt.subplots(ncols=2, figsize=(20, 7))

# Scatter plot for Pink Cab
sns.scatterplot(data=pinkcab, x='KM_Travelled', y='Price_Charged', ax=axp)
axp.set_title('Price vs Distance in Pink Cab', fontsize=20)
axp.set_xticklabels(axp.get_xticklabels(), rotation=0, fontsize=15)

# Scatter plot for Yellow Cab
sns.scatterplot(data=yellowcab, x='KM_Travelled', y='Price_Charged', ax=axy)
axy.set_title('Price vs Distance in Yellow Cab', fontsize=20)
axy.set_xticklabels(axy.get_xticklabels(), rotation=0, fontsize=15)

plt.show()

# %%
pinkcab['KM_Travelled'].corr(pinkcab['Price_Charged'])
# Out:
# 0.9277652782594862

# %%
yellowcab['KM_Travelled'].corr(yellowcab['Price_Charged'])
# Out:
# 0.8597086294478473

# %%
plotp= Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
ploty= Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.bar(plotp.index-0.2, plotp.values, width=0.4, color='pink', align='center', label='pink cab')
ax.bar(plotp.index+0.2, ploty.values, width=0.4, color='yellow', align='center', label='yellow cab')
plt.title("pink vs yellow", fontsize=15)
plt.xlabel('years', fontsize=12)
plt.ylabel('transactions number', fontsize=12)
plt.legend()
plt.show()

# %%
Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Price_Charged.mean()
# Out:
# Year
# 2016    315.850071
# 2017    315.535059
# 2018    301.538134
# Name: Price_Charged, dtype: float64

# %%
Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Cost_of_Trip.mean()
# Out:
# Year
# 2016    247.039209
# 2017    248.820917
# 2018    248.413839
# Name: Cost_of_Trip, dtype: float64

# %%
plot1= Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
plot2= Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Price_Charged.mean()
plot3= Cab_Data[Cab_Data.Company=='Pink Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot3.values, width=0.4, color='green', align='center', label='cost of the trip')
ax.bar(plotp.index+0.2, plot2.values, width=0.4, color='silver', align='center', label='price')
plt.title("pink cab", fontsize=15)
plt.xlabel('years', fontsize=12)
plt.ylabel('profit', fontsize=12)
plt.legend()
plt.show()

# %%
Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Price_Charged.mean()
# Out:
# Year
# 2016    468.230462
# 2017    466.278438
# 2018    440.893159
# Name: Price_Charged, dtype: float64

# %%
Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Cost_of_Trip.mean()
# Out:
# Year
# 2016    298.536761
# 2017    297.861544
# 2018    297.442400
# Name: Cost_of_Trip, dtype: float64

# %%
plot1= Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plot2= Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Price_Charged.mean()
plot3= Cab_Data[Cab_Data.Company=='Yellow Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot3.values, width=0.4, color='green', align='center', label='cost of the trip')
ax.bar(plotp.index+0.2, plot2.values, width=0.4, color='silver', align='center', label='price')
plt.title("Yellow cab", fontsize=15)
plt.xlabel('years', fontsize=12)
plt.ylabel('profit', fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=Cab_Data, x=pinkcab["KM_Travelled"], y=pinkcab['Cost_of_Trip'], hue="City")
plt.title('KM Travelled (pink cab)',fontsize = 14)
plt.ylabel('Cost of trip',fontsize = 12)
plt.xlabel('KM Travelled',fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=Cab_Data, x=yellowcab["KM_Travelled"], y=yellowcab['Cost_of_Trip'], hue="City")
plt.title('KM Travelled (yellow cab)',fontsize = 14)
plt.ylabel('Cost of trip',fontsize = 12)
plt.xlabel('KM Travelled',fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=Cab_Data, x=pinkcab["KM_Travelled"], y=pinkcab['Price_Charged'], hue="City")
plt.title('KM Travelled (pink cab)',fontsize = 14)
plt.ylabel('price',fontsize = 12)
plt.xlabel('KM Travelled',fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=Cab_Data, x=yellowcab["KM_Travelled"], y=yellowcab['Price_Charged'], hue="City")
plt.title('KM Travelled (yellow cab)',fontsize = 14)
plt.ylabel('Price',fontsize = 12)
plt.xlabel('KM Travelled',fontsize = 12)
plt.show()

# %%
left = Cab_Data.set_index(['Transaction_ID'])
right = transaction_id.set_index(['Transaction_ID'])
data = left.join(right)
data.head()
# Out:
#                  Company        City  KM_Travelled  Price_Charged  \
# Transaction_ID
# 10000011        Pink Cab  ATLANTA GA         30.45         370.95
# 10000012        Pink Cab  ATLANTA GA         28.62         358.52
# 10000013        Pink Cab  ATLANTA GA          9.04         125.20
# 10000014        Pink Cab  ATLANTA GA         33.17         377.40
# 10000015        Pink Cab  ATLANTA GA          8.73         114.62
#
#                 Cost_of_Trip  Month  Year  Customer_ID Payment_Mode
# Transaction_ID
# 10000011             313.635      1  2016        29290         Card
# 10000012             334.854      1  2016        27703         Card
# 10000013              97.632      1  2016        28712         Cash
# 10000014             351.602      1  2016        28020         Cash
# 10000015              97.776      1  2016        27182         Card

# %%
left = data.set_index([data.index,'Customer_ID'])
right = customer_id.set_index(['Customer_ID'])
data = left.join(right)
data.head()
# Out:
#                              Company        City  KM_Travelled  Price_Charged  \
# Transaction_ID Customer_ID
# 10000011       29290        Pink Cab  ATLANTA GA         30.45         370.95
# 10000012       27703        Pink Cab  ATLANTA GA         28.62         358.52
# 10000013       28712        Pink Cab  ATLANTA GA          9.04         125.20
# 10000014       28020        Pink Cab  ATLANTA GA         33.17         377.40
# 10000015       27182        Pink Cab  ATLANTA GA          8.73         114.62
#
#                             Cost_of_Trip  Month  Year Payment_Mode Gender  \
# Transaction_ID Customer_ID
# 10000011       29290             313.635      1  2016         Card   Male
# 10000012       27703             334.854      1  2016         Card   Male
# 10000013       28712              97.632      1  2016         Cash   Male
# 10000014       28020             351.602      1  2016         Cash   Male
# ...

# %%
left = data.set_index([data.index,'City'])
right = city.set_index(['City'])
data = left.join(right)
data.head()
# Out:
#                                         Company  KM_Travelled  Price_Charged  \
# Transaction_ID Customer_ID City
# 10000011       29290       ATLANTA GA  Pink Cab         30.45         370.95
# 10000012       27703       ATLANTA GA  Pink Cab         28.62         358.52
# 10000013       28712       ATLANTA GA  Pink Cab          9.04         125.20
# 10000014       28020       ATLANTA GA  Pink Cab         33.17         377.40
# 10000015       27182       ATLANTA GA  Pink Cab          8.73         114.62
#
#                                        Cost_of_Trip  Month  Year Payment_Mode  \
# Transaction_ID Customer_ID City
# 10000011       29290       ATLANTA GA       313.635      1  2016         Card
# 10000012       27703       ATLANTA GA       334.854      1  2016         Card
# 10000013       28712       ATLANTA GA        97.632      1  2016         Cash
# 10000014       28020       ATLANTA GA       351.602      1  2016         Cash
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 359392 entries, (10000011, 29290, 'ATLANTA GA') to (10440107, 52917, 'WASHINGTON DC')
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Company             359392 non-null  object
#  1   KM_Travelled        359392 non-null  float64
#  2   Price_Charged       359392 non-null  float64
#  3   Cost_of_Trip        359392 non-null  float64
#  4   Month               359392 non-null  int64
#  5   Year                359392 non-null  int64
#  6   Payment_Mode        359392 non-null  object
#  7   Gender              359392 non-null  object
#  8   Age                 359392 non-null  int64
#  9   Income_(USD/Month)  359392 non-null  int64
#  10  Population          359392 non-null  object
#  11  Users               359392 non-null  object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 48.2+ MB

# %%
data= data.reset_index()

# %%
data = data.rename(columns={'Income_(USD/Month)':'income'})

# %%
city_users= data.groupby('City').Users.count()
city_users
# Out:
# City
# ATLANTA GA         7557
# AUSTIN TX          4896
# BOSTON MA         29692
# CHICAGO IL        56625
# DALLAS TX          7017
# DENVER CO          3825
# LOS ANGELES CA    48033
# MIAMI FL           6454
# NASHVILLE TN       3010
# NEW YORK NY       99885
# ORANGE COUNTY      3982
# PHOENIX AZ         2064
# PITTSBURGH PA      1313
# SACRAMENTO CA      2367
# SAN DIEGO CA      20488
# SEATTLE WA         7997
# SILICON VALLEY     8519
# TUCSON AZ          1931
# WASHINGTON DC     43737
# Name: Users, dtype: int64

# %%
city_y = data[data.Company=='Yellow Cab'].groupby('City').Transaction_ID.count()
city_y
# Out:
# City
# ATLANTA GA         5795
# AUSTIN TX          3028
# BOSTON MA         24506
# CHICAGO IL        47264
# DALLAS TX          5637
# DENVER CO          2431
# LOS ANGELES CA    28168
# MIAMI FL           4452
# NASHVILLE TN       1169
# NEW YORK NY       85918
# ORANGE COUNTY      2469
# PHOENIX AZ         1200
# PITTSBURGH PA       631
# SACRAMENTO CA      1033
# SAN DIEGO CA       9816
# SEATTLE WA         5265
# SILICON VALLEY     4722
# TUCSON AZ          1132
# WASHINGTON DC     40045
# Name: Transaction_ID, dtype: int64

# %%
labels= city_users.index
values = city_users.values
fig, ax1 = plt.subplots(figsize=(15,20))
ax1.pie(values, labels= labels, autopct='%1.1f%%', shadow= False, startangle=90)
ax1.axis('equal')
plt.title('city users')
plt.show()

# %%
labels = city_y.index
values = city_y.values
figp, axp = plt.subplots(figsize=(15,20))
axp.pie(values , labels=labels, autopct='%1.1f%%',shadow=False, startangle=90)
axp.axis('equal')

plt.title('cities transaction(yellow cab)')
plt.show()

# %%
city_p = data[data.Company=='Pink Cab'].groupby('City').Transaction_ID.count()
city_p
# Out:
# City
# ATLANTA GA         1762
# AUSTIN TX          1868
# BOSTON MA          5186
# CHICAGO IL         9361
# DALLAS TX          1380
# DENVER CO          1394
# LOS ANGELES CA    19865
# MIAMI FL           2002
# NASHVILLE TN       1841
# NEW YORK NY       13967
# ORANGE COUNTY      1513
# PHOENIX AZ          864
# PITTSBURGH PA       682
# SACRAMENTO CA      1334
# SAN DIEGO CA      10672
# SEATTLE WA         2732
# SILICON VALLEY     3797
# TUCSON AZ           799
# WASHINGTON DC      3692
# Name: Transaction_ID, dtype: int64

# %%
labels= city_p.index
values = city_p.values
fig, ax1 = plt.subplots(figsize=(15,20))
ax1.pie(values, labels= labels, autopct='%1.1f%%', shadow= False, startangle=90)
ax1.axis('equal')
plt.title('cities transaction (pink cab)')
plt.show()

# %%
gender_y=data[data.Company=='Yellow Cab'].groupby('Gender').Price_Charged.mean()

# %%
labels = gender_y.index
values = gender_y.values
figp, axp = plt.subplots(figsize=(15,7))
axp.pie(values , labels=labels, autopct='%1.1f%%',shadow=False, startangle=90)
axp.axis('equal')

plt.title('Price per Gender (Yellow Cab)')
plt.show()

# %%
gender_p=data[data.Company=='Pink Cab'].groupby('Gender').Price_Charged.mean()

# %%
labels = gender_p.index
values = gender_p.values
figp, axp = plt.subplots(figsize=(15,7))
axp.pie(values , labels=labels, autopct='%1.1f%%',shadow=False, startangle=90)
axp.axis('equal')

plt.title('Price per Gender (Pink Cab)')
plt.show()

# %%
gender_cab=data.groupby(['Company','Gender']).Customer_ID.nunique()
gender_cab
# Out:
# Company     Gender
# Pink Cab    Female    14819
#             Male      17511
# Yellow Cab  Female    18394
#             Male      21502
# Name: Customer_ID, dtype: int64

# %%
labels = gender_cab.index
values = gender_cab.values
figp, axp = plt.subplots(figsize=(15,7))
axp.pie(values , labels=labels, autopct='%1.1f%%',shadow=False, startangle=90)
axp.axis('equal')

plt.title('Gender-specific customer distribution for each cab.')
plt.show()

# %%
data['Margins'] = (data['Price_Charged']- data['Cost_of_Trip'])
data.head()
# Out:
#    Transaction_ID  Customer_ID        City   Company  KM_Travelled  \
# 0        10000011        29290  ATLANTA GA  Pink Cab         30.45
# 1        10000012        27703  ATLANTA GA  Pink Cab         28.62
# 2        10000013        28712  ATLANTA GA  Pink Cab          9.04
# 3        10000014        28020  ATLANTA GA  Pink Cab         33.17
# 4        10000015        27182  ATLANTA GA  Pink Cab          8.73
#
#    Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  income  \
# 0         370.95       313.635      1  2016         Card   Male   28   10813
# 1         358.52       334.854      1  2016         Card   Male   27    9237
# 2         125.20        97.632      1  2016         Cash   Male   53   11242
# 3         377.40       351.602      1  2016         Cash   Male   23   23327
# 4         114.62        97.776      1  2016         Card   Male   33    8536
#
#   Population     Users  Margins
# 0   814,885    24,701    57.315
# 1   814,885    24,701    23.666
# ...

# %%
data.tail()
# Out:
#         Transaction_ID  Customer_ID           City     Company  KM_Travelled  \
# 359387        10440101        52392  WASHINGTON DC  Yellow Cab          4.80
# 359388        10440104        53286  WASHINGTON DC  Yellow Cab          8.40
# 359389        10440105        52265  WASHINGTON DC  Yellow Cab         27.75
# 359390        10440106        52175  WASHINGTON DC  Yellow Cab          8.80
# 359391        10440107        52917  WASHINGTON DC  Yellow Cab         12.76
#
#         Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  \
# 359387          69.24       63.3600      1  2018         Cash   Male   24
# 359388         113.75      106.8480      1  2018         Cash   Male   32
# 359389         437.07      349.6500      1  2018         Cash   Male   56
# 359390         146.19      114.0480      1  2018         Card   Male   32
# 359391         191.58      177.6192      1  2018         Card   Male   20
#
#         income Population      Users  Margins
# ...

# %%
df = data[['KM_Travelled','Price_Charged','Cost_of_Trip','Month','Year','Age','income','Margins']]
df.corr()
# Out:
#                KM_Travelled  Price_Charged  Cost_of_Trip     Month      Year  \
# KM_Travelled       1.000000       0.835753      0.981848 -0.001773 -0.001094
# Price_Charged      0.835753       1.000000      0.859812 -0.059639 -0.036903
# Cost_of_Trip       0.981848       0.859812      1.000000 -0.008309 -0.001766
# Month             -0.001773      -0.059639     -0.008309  1.000000 -0.033169
# Year              -0.001094      -0.036903     -0.001766 -0.033169  1.000000
# Age               -0.000369      -0.003084     -0.000189 -0.002376 -0.000497
# income            -0.000544       0.003228     -0.000633  0.000585 -0.001679
# Margins            0.462768       0.864154      0.486056 -0.093886 -0.061420
#
#                     Age    income   Margins
# KM_Travelled  -0.000369 -0.000544  0.462768
# Price_Charged -0.003084  0.003228  0.864154
# Cost_of_Trip  -0.000189 -0.000633  0.486056
# Month         -0.002376  0.000585 -0.093886
# Year          -0.000497 -0.001679 -0.061420
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
plt.show()

# %%
city_marg= data[data.Month==12].groupby('City').Margins.mean()
city_marg
# Out:
# City
# ATLANTA GA         96.252930
# AUSTIN TX          91.891400
# BOSTON MA          62.360750
# CHICAGO IL         52.396687
# DALLAS TX         109.465216
# DENVER CO         111.138893
# LOS ANGELES CA     81.752667
# MIAMI FL          100.150911
# NASHVILLE TN       81.459593
# NEW YORK NY       258.421581
# ORANGE COUNTY      76.134553
# PHOENIX AZ         76.922806
# PITTSBURGH PA      57.105846
# SACRAMENTO CA      27.119039
# SAN DIEGO CA       70.382592
# SEATTLE WA         76.515311
# SILICON VALLEY    167.087114
# TUCSON AZ          84.105100
# WASHINGTON DC      62.742899
# Name: Margins, dtype: float64

# %%
d1= data[(data.Company=='Pink Cab')&(data.City=='NEW YORK NY')].groupby(['Year','Month']).Margins.mean()
d2 = data[(data.Company=='Yellow Cab')&(data.City=='NEW YORK NY')].groupby(['Year','Month']).Margins.mean()

d11 = pd.DataFrame({'Margins_pink':d1.values,'Transactions_pink':data[data.Company=='Pink Cab'].groupby(['Year','Month']).Transaction_ID.count().values})
d22 = pd.DataFrame({'Margins_yellow':d2.values,'Transactions_yellow':data[data.Company=='Yellow Cab'].groupby(['Year','Month']).Transaction_ID.count().values})

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x=d11.Transactions_pink, y=d11.Margins_pink)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x=d22.Transactions_yellow, y=d22.Margins_yellow)
plt.show()

# %%
a = data[(data.Gender=='Female')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Gender=='Male')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a statistical difference')
else:
    print('We accept null hypothesis that there is no statistical difference')
    
print('P value is ', p_value)
# Out:
# 116000 158681
# We accept alternate hypothesis that there is a statistical difference
# P value is  6.060473042494056e-25

# %%
a = data[(data.Gender=='Female')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Gender=='Male')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a statistical difference')
else:
    print('We accept null hypothesis that there is no statistical difference')
    
print('P value is ', p_value)
# Out:
# 37480 47231
# We accept null hypothesis that there is no statistical difference
# P value is  0.115153059004258

# %%
data[data.Age<=50].groupby('Company').Margins.mean()
data[data.Age>=50].groupby('Company').Margins.mean()
# Out:
# Company
# Pink Cab       62.156779
# Yellow Cab    157.482752
# Name: Margins, dtype: float64

# %%
a = data[(data.Age<=50)&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Age>=50)&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a difference')
else:
    print('We accept null hypothesis that there is no difference')
    
print('P value is ', p_value)
# Out:
# 71228 14405
# We accept null hypothesis that there is no difference
# P value is  0.3905344473325604

# %%
a = data[(data.Age<=50)&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Age>=50)&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a difference')
else:
    print('We accept null hypothesis that there is no difference')
    
print('P value is ', p_value)
# Out:
# 231480 46368
# We accept alternate hypothesis that there is a difference
# P value is  3.893841736668538e-05

# %%
a = data[(data.Payment_Mode=='Cash')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Payment_Mode=='Card')&(data.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a difference')
else:
    print('We accept null hypothesis that there is no difference')
    
print('P value is ', p_value)
# Out:
# 33992 50719
# We accept null hypothesis that there is no difference
# P value is  0.7900465828793286

# %%
a = data[(data.Payment_Mode=='Cash')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = data[(data.Payment_Mode=='Card')&(data.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a difference')
else:
    print('We accept null hypothesis that there is no difference')
    
print('P value is ', p_value)
# Out:
# 109896 164785
# We accept null hypothesis that there is no difference
# P value is  0.29330606382987284

# %%
data.head()
# Out:
#    Transaction_ID  Customer_ID        City   Company  KM_Travelled  \
# 0        10000011        29290  ATLANTA GA  Pink Cab         30.45
# 1        10000012        27703  ATLANTA GA  Pink Cab         28.62
# 2        10000013        28712  ATLANTA GA  Pink Cab          9.04
# 3        10000014        28020  ATLANTA GA  Pink Cab         33.17
# 4        10000015        27182  ATLANTA GA  Pink Cab          8.73
#
#    Price_Charged  Cost_of_Trip  Month  Year Payment_Mode Gender  Age  income  \
# 0         370.95       313.635      1  2016         Card   Male   28   10813
# 1         358.52       334.854      1  2016         Card   Male   27    9237
# 2         125.20        97.632      1  2016         Cash   Male   53   11242
# 3         377.40       351.602      1  2016         Cash   Male   23   23327
# 4         114.62        97.776      1  2016         Card   Male   33    8536
#
#   Population     Users  Margins
# 0   814,885    24,701    57.315
# 1   814,885    24,701    23.666
# ...

# %%
data.to_csv('master_data.csv',index = False)
